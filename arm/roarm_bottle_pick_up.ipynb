# %%
import numpy as np
import time

#from beachbot.robot.jetsonrobotv1 import RoArmM1_Custom3FingerGripper
from beachbot.manipulators.roarmm1 import RoArmM1_Custom3FingerGripper

# %%
robot = RoArmM1_Custom3FingerGripper()

# %%
robot.open_gripper()
robot.write_dspl("Pickup")
robot.pickup()
robot.close_gripper()
robot.write_dspl("Toss")
robot.toss()
robot.open_gripper()
#robot.pickup()
# Out:
# Distance to target:  204.31665191581226
# Current joint angles:  [183.2519531, -12.86132813, -0.703125, -110.1269531, 0.02506510444444427]
# Target joint angles:  [177.81160471  17.53147799   1.66309159  82.71853531  60.        ]
# Distance to target:  204.31235250597663
# Current joint angles:  [183.2519531, -12.86132813, -0.703125, -110.1269531, 0.039713541666666664]
# Target joint angles:  [177.81160471  17.53147799   1.66309159  82.71853531  60.        ]
# Distance to target:  202.80990013904892
# Current joint angles:  [181.3183594, -12.21679688, 0.439453125, -108.7207031, 0.13248697944444426]
# Target joint angles:  [177.81160471  17.53147799   1.66309159  82.71853531  60.        ]
# Distance to target:  199.5162299867235
# Current joint angles:  [178.2421875, -10.13671875, 0.791015625, -105.6445313, 0.33756510444444426]
# Target joint angles:  [177.81160471  17.53147799   1.66309159  82.71853531  60.        ]
# Distance to target:  196.09111838255538
# ...

# %%
#robot.open_gripper(0.0)

robot.close_gripper()
# Out:
# False

# %%
qs = robot.get_joint_angles()
print(qs)
# Out:
# [177.8027344, 60.234375, 2.28515625, 96.328125, 0.02506510444444427]

# %%
if qs[0]>175:
    qs[0]=170
else:
    qs[0]=180
qs[4]=0.9
robot.set_joint_targets(qs)

# %%
robot.arm
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 robot.arm
#
# AttributeError: 'RoArmM1_Custom3FingerGripper' object has no attribute 'arm'

# %%
write: {"T": 1, "P1": 180, "P2": -11.45507813, "P3": 101.6015625, "P4": 46.31835938, "P5": 58.2, "S1": 400, "S2": 1200, "S3": 400, "S4": 400, "S5": 400, "A1": 60, "A2": 60, "A3": 60, "A4": 60, "A5": 60}
in lock
returned!
write done
